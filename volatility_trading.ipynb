# %%
import pandas as pd

# %%
df = pd.read_csv('volatility_03_02_2017.csv')
df['date'] = pd.to_datetime(df['date'], format='%y-%m-%d')
df.head()
# Out:
#   Symbol  hv20  hv50  hv100       date     iv days_calculated  percentile  \
# 0   $AUM   8.0  10.0   10.0 2017-01-27  10.48             597        23.0
# 1   $AUX   8.0  10.0   10.0 2017-01-27  12.94             599         1.0
# 2   $BKX  19.0  18.0   20.0 2016-07-05  32.02             250        98.0
# 3   $BPX  13.0  11.0   11.0 2017-01-27  12.11             599        62.0
# 4   $BRB  11.0  12.0   16.0 2017-01-27  22.00             197         2.0
#
#     close
# 0   75.50
# 1  132.47
# 2   92.85
# 3   79.69
# 4  314.10

# %%
df[df.percentile > 0].sort_values('percentile')
# Out:
#      Symbol   hv20   hv50  hv100       date      iv days_calculated  \
# 2664   MNKD  115.0  125.0  163.0 2016-12-30  220.00         492/100
# 3963   TKAI   69.0  100.0  115.0 2016-10-13  211.94          37/100
# 2552   MATW   19.0   23.0   21.0 2017-01-27   18.28             153
# 1139    DIA    6.0    6.0    9.0 2017-01-27    7.95             600
# 987     CST    2.8    2.8    3.1 2016-10-11    5.95             510
# 3480    RWM   15.0   14.0   16.0 2017-01-27   15.82             588
# 3721    SNX   25.0   21.0   26.0 2017-01-27   24.22             600
# 2611    MFS   28.0   21.0   30.0 2017-01-27   27.31             218
# 3995    TOT   14.0   17.0   19.0 2017-01-27   15.95             600
# 1003   @CTN   15.0   13.0   16.0 2017-01-27   13.37             588
# 433     BBH   18.0   18.0   24.0 2017-01-27   21.68             600
# 664    CAPL   21.0   22.0   19.0 2017-01-26   19.85             516
# 2781   NCMI   17.0   22.0   23.0 2017-01-27   20.94             515
# ...
